# %%
import pandas as pd

# %%
df = pd.read_excel('Base_CNPJ_Final.xlsx', sheet_name='CNPJs')

# %%
df.tail(20)
# Out:
#                   cnpj  matriz_filial_n matriz_filial  \
# 491967  19454287000158                1        MATRIZ
# 491968  19454311000159                1        MATRIZ
# 491969  19454802000108                1        MATRIZ
# 491970  19454905000160                1        MATRIZ
# 491971  19454911000117                1        MATRIZ
# 491972  19455010000140                1        MATRIZ
# 491973  19455011000194                1        MATRIZ
# 491974  19455073000104                1        MATRIZ
# 491975  19455085000120                1        MATRIZ
# 491976  19455248000175                1        MATRIZ
# 491977  19455249000110                1        MATRIZ
# 491978  19455364000194                1        MATRIZ
# 491979  19455364000275                2        FILIAL
# 491980  19455438000192                1        MATRIZ
# 491981  19455529000128                1        MATRIZ
# 491982  19455853000146                1        MATRIZ
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   cnpj  matriz_filial_n matriz_filial  \
# 0                35572                2        FILIAL
# 1               773131                2        FILIAL
# 2          70478000198                1        MATRIZ
# 3          78179000108                1        MATRIZ
# 4          79807000161                1        MATRIZ
# ...                ...              ...           ...
# 491982  19455853000146                1        MATRIZ
# 491983  19455862000137                1        MATRIZ
# 491984  19455950000139                1        MATRIZ
# 491985  19456028000166                1        MATRIZ
# 491986  19456050000106                1        MATRIZ
#
#                                              razao_social  \
# 0                                      BANCO DO BRASIL SA
# 1                                      BANCO DO BRASIL SA
# 2                            M.S.T. BOLSAS E BRINDES LTDA
# ...

# %%
df.columns
# Out:
# Index(['cnpj', 'matriz_filial_n', 'matriz_filial', 'razao_social',
#        'nome_fantasia', 'situacao_cadastral', 'data_situacao_cadastral',
#        'codigo_natureza_juridica', 'data_inicio_atividade',
#        'tempo_atividade_dias', 'tempo_atividade_mês', 'tempo_atividade_ano',
#        'cnae_fiscal', 'classe_cnae', 'subclasse_cnae',
#        'descricao_tipo_logradouro', 'logradouro', 'numero', 'complemento',
#        'bairro', 'cep', 'uf', 'codigo_municipio', 'cidade', 'telefone_1',
#        'telefone_2', 'telefone_3', 'email', 'qualificacao_responsavel',
#        'capital_social_empresa', 'porte_empresa', 'opcao_pelo_simples',
#        'porte', 'faturamento_presumido', 'data_opcao_pelo_simples',
#        'data_exclusao_simples', 'tempo_exc_simples_dias',
#        'tempo_exc_simples_mes', 'opcao_pelo_mei', 'situacao_especial',
#        'data_situacao_especial', 'socios', 'full_address', 'lon', 'lat',
#        'google_1', 'google_2', 'jus_brasil', 'jus_brasil_cnpj'],
# ...

# %%
df.count()
# Out:
# cnpj                         491987
# matriz_filial_n              491987
# matriz_filial                491987
# razao_social                 491987
# nome_fantasia                289621
# situacao_cadastral           491987
# data_situacao_cadastral      491987
# codigo_natureza_juridica     491987
# data_inicio_atividade        491987
# tempo_atividade_dias         491987
# tempo_atividade_mês          491987
# tempo_atividade_ano          491987
# cnae_fiscal                  491987
# classe_cnae                  491715
# subclasse_cnae               491970
# descricao_tipo_logradouro    488450
# logradouro                   491955
# numero                       491986
# complemento                  190115
# bairro                       491899
# cep                          491987
# uf                           491987
# codigo_municipio             491987
# cidade                       491987
# telefone_1                   440777
# telefone_2                   100460
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491987 entries, 0 to 491986
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   cnpj                       491987 non-null  int64
#  1   matriz_filial_n            491987 non-null  int64
#  2   matriz_filial              491987 non-null  object
#  3   razao_social               491987 non-null  object
#  4   nome_fantasia              289621 non-null  object
#  5   situacao_cadastral         491987 non-null  int64
#  6   data_situacao_cadastral    491987 non-null  datetime64[ns]
#  7   codigo_natureza_juridica   491987 non-null  int64
#  8   data_inicio_atividade      491987 non-null  datetime64[ns]
#  9   tempo_atividade_dias       491987 non-null  int64
#  10  tempo_atividade_mês        491987 non-null  float64
#  11  tempo_atividade_ano        491987 non-null  float64
#  12  cnae_fiscal                491987 non-null  int64
# ...

# %%
import sqlalchemy

# %%
#Criando a engine para a conexão.

engine = sqlalchemy.create_engine('mysql+pymysql://root:375701@localhost:3306/yol')

# %%
df_cnpj = pd.read_sql_table('cnpj', engine)

# %%
df_cnpj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   IDCNPJ                     0 non-null      int64
#  1   CNPJ                       0 non-null      object
#  2   matriz_filial_n            0 non-null      object
#  3   matriz_filial              0 non-null      object
#  4   nome_fantasia              0 non-null      object
#  5   situacao_cadastral         0 non-null      object
#  6   data_situacao_cadastral    0 non-null      datetime64[ns]
#  7   codigo_natureza_juridica   0 non-null      object
#  8   data_inicio_atividade      0 non-null      datetime64[ns]
#  9   tempo_atividade_dias       0 non-null      object
#  10  tempo_atividade_mês        0 non-null      float64
#  11  tempo_atividade_ano        0 non-null      float64
#  12  cnae_fiscal                0 non-null      object
# ...

# %%
#importanto para o mysql

df.to_sql(
    name = 'cnpj_final',
    con = engine,
    index = True,
)
