# %% [markdown]
# ## Limpando o Dataset - WIKIPÉDIA

# %% [markdown]
# - Usando o web scraping, conseguimos retirar algumas informações importantes, para um furutra projeto de Machine Learning. Agora por meio do data cleaning, iremos limpar os dados que aind apossuem resqeucios da web, nõa podendo ser trabalhados para a utilização de algoritmos de ML.
#
# - Irei portando limpar os dados para um modo de visualização mais claro, para trazer valor ao dataset. Aqui, entenderemos as colunas do conjunto de dados e tentaremos remover cadeias e valores desnecessários que não agregam valor ao conjunto de dados.

# %%
#Lendo a arquivo .csv retirado do Wikipedia.

import re
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("Dataset.csv")

# %%
dataset.head(100)
# Out:
#    Country/Territory      US$                              Total Area  \
# 0         Luxembourg  113,196       2,586.4 km2 (998.6 sq mi) (167th)
# 1        Switzerland   83,716       41,285 km2 (15,940 sq mi) (132nd)
# 2              Macau   81,151                  115.3 km2 (44.5 sq mi)
# 3             Norway   77,975  385,207 km2 (148,729 sq mi)[7] (67thb)
# 4            Ireland   77,771       70,273 km2 (27,133 sq mi) (118th)
# ..               ...      ...                                     ...
# 95           Jamaica    5,460        10,991 km2 (4,244 sq mi) (160th)
# 96           Albania    5,372       28,748 km2 (11,100 sq mi) (140th)
# 97            Guyana    5,252       214,970 km2 (83,000 sq mi) (83rd)
# 98             Libya    5,019    1,759,541 km2 (679,363 sq mi) (16th)
# 99            Belize    4,925  22,966 km2 (8,867 sq mi)[3][4] (147th)
#
#         Percentage Water            Total Nominal GDP      Per Capita GDP
# 0                  0.60%    $69.453 billion[3] (69th)   $113,196[3] (1st)
# 1                    4.2       $704 billion[7] (20th)    $82,950[7] (2nd)
# 2                   73.7    $54.545 billion[3] (83rd)    $81,728[3] (3rd)
# 3                   5.7c       $443 billion[9] (22nd)    $82,711[9] (3rd)
# 4                   2.00   $384.940 billion[5] (32nd)    $77,771[5] (4th)
# ..                   ...                          ...                 ...
# 95                   1.5   $15.424 billion[8] (119th)    $5,393[8] (95th)
# 96                   4.7           $16.753 billion[3]           $5,847[3]
# 97                   8.4            $8.065 billion[6]          $10,249[6]
# 98  6,871,287[3] (108th)      $51.330 billion[4] (98)           $7,803[4]
# 99                   0.8            $1.987 billion[7]           $4,890[7]
#
# [100 rows x 6 columns]

# %% [markdown]
# - Substituindo o nome dos headers

# %%
dataset.rename(columns={"Country/Territory": "Country"}, inplace = True)
dataset.rename(columns={"Total Area": "Total Area (km2)"}, inplace = True)

# %%
dataset.head(5)
# Out:
#          Country      US$                        Total Area (km2)  \
# 0     Luxembourg  113,196       2,586.4 km2 (998.6 sq mi) (167th)
# 1    Switzerland   83,716       41,285 km2 (15,940 sq mi) (132nd)
# 2          Macau   81,151                  115.3 km2 (44.5 sq mi)
# 3         Norway   77,975  385,207 km2 (148,729 sq mi)[7] (67thb)
# 4        Ireland   77,771       70,273 km2 (27,133 sq mi) (118th)
#
#   Percentage Water            Total Nominal GDP      Per Capita GDP
# 0            0.60%    $69.453 billion[3] (69th)   $113,196[3] (1st)
# 1              4.2       $704 billion[7] (20th)    $82,950[7] (2nd)
# 2             73.7    $54.545 billion[3] (83rd)    $81,728[3] (3rd)
# 3             5.7c       $443 billion[9] (22nd)    $82,711[9] (3rd)
# 4             2.00   $384.940 billion[5] (32nd)    $77,771[5] (4th)

# %% [markdown]
# - Vemos que quase todas as colunas têm células que possuem dados entre parênteses e colchetes, o que não é necessário. Assim, podemos primeiro remover todas as parênteses, colchetes e o conteúdo dentro deles.

# %%
dataset.columns
# Out:
# Index(['Country', 'US$', 'Total Area (km2)', 'Percentage Water',
#        'Total Nominal GDP', 'Per Capita GDP'],
#       dtype='object')

# %%
for column in dataset.columns:
    dataset[column] = dataset[column].str.replace(r"\(.*\)", "")
    dataset[column] = dataset[column].str.replace(r"\[.*\]", "")

# %%
dataset.head(5)
# Out:
#          Country      US$ Total Area (km2) Percentage Water  \
# 0     Luxembourg  113,196     2,586.4 km2             0.60%
# 1    Switzerland   83,716      41,285 km2               4.2
# 2          Macau   81,151       115.3 km2              73.7
# 3         Norway   77,975     385,207 km2              5.7c
# 4        Ireland   77,771      70,273 km2              2.00
#
#     Total Nominal GDP Per Capita GDP
# 0    $69.453 billion       $113,196
# 1       $704 billion        $82,950
# 2    $54.545 billion        $81,728
# 3       $443 billion        $82,711
# 4   $384.940 billion        $77,771

# %%
#Agora remova a percentagem da coluna 'Percentage Water'

dataset['Percentage Water'] = dataset['Percentage Water'].str.strip('%')
dataset['Percentage Water'] = dataset['Percentage Water'].str.strip()
dataset['Percentage Water'] = dataset['Percentage Water'].str.strip('c')

# %%
dataset['Percentage Water']
# Out:
# 0            0.60
# 1             4.2
# 2            73.7
# 3             5.7
# 4            2.00
#           ...
# 175          0.02
# 176          20.6
# 177          0.14
# 178            10
# 179    12,778,250
# Name: Percentage Water, Length: 180, dtype: object

# %%
dataset['Total Area (km2)']
# Out:
# 0        2,586.4 km2
# 1         41,285 km2
# 2          115.3 km2
# 3        385,207 km2
# 4         70,273 km2
#             ...
# 175    1,267,000 km2
# 176      118,484 km2
# 177      117,600 km2
# 178       27,834 km2
# 179      619,745 km2
# Name: Total Area (km2), Length: 180, dtype: object

# %%
dataset
# Out:
#            Country      US$ Total Area (km2) Percentage Water  \
# 0       Luxembourg  113,196     2,586.4 km2              0.60
# 1      Switzerland   83,716      41,285 km2               4.2
# 2            Macau   81,151       115.3 km2              73.7
# 3           Norway   77,975     385,207 km2               5.7
# 4          Ireland   77,771      70,273 km2              2.00
# ..             ...      ...              ...              ...
# 175          Niger      405   1,267,000 km2              0.02
# 176         Malawi      370     118,484 km2              20.6
# 177        Eritrea      342     117,600 km2              0.14
# 178        Burundi      309      27,834 km2                10
# 179    South Sudan      275     619,745 km2        12,778,250
#
#       Total Nominal GDP Per Capita GDP
# 0      $69.453 billion       $113,196
# 1         $704 billion        $82,950
# 2      $54.545 billion        $81,728
# 3         $443 billion        $82,711
# 4     $384.940 billion        $77,771
# ..                  ...            ...
# 175     $9.869 billion           $510
# 176      $7.436 billion           $367
# 177     $8.116 billion         $1,295
# 178      $3.573 billion           $310
# 179      $3.194 billion           $246
#
# [180 rows x 6 columns]

# %%
#setando para trabalhar com a coluna country

#df.set_index("Country")
# Out:
#                    US$ Total Area (km2) Percentage Water   Total Nominal GDP  \
# Country
#  Luxembourg    113,196     2,586.4 km2              0.60    $69.453 billion
#   Switzerland   83,716      41,285 km2               4.2       $704 billion
#  Macau          81,151       115.3 km2              73.7    $54.545 billion
#  Norway         77,975     385,207 km2               5.7       $443 billion
#  Ireland        77,771      70,273 km2              2.00   $384.940 billion
# ...                ...              ...              ...                 ...
#  Niger             405   1,267,000 km2              0.02     $9.869 billion
#  Malawi            370     118,484 km2              20.6      $7.436 billion
#  Eritrea           342     117,600 km2              0.14     $8.116 billion
#  Burundi           309      27,834 km2                10      $3.573 billion
#  South Sudan       275     619,745 km2        12,778,250      $3.194 billion
#
#               Per Capita GDP
# Country
#  Luxembourg        $113,196
#   Switzerland       $82,950
#  Macau              $81,728
#  Norway             $82,711
#  Ireland            $77,771
# ...                      ...
#  Niger                 $510
#  Malawi                 $367
#  Eritrea             $1,295
#  Burundi                $310
#  South Sudan            $246
#
# [180 rows x 5 columns]

# %%
area = dataset.iloc[x]['Total Area (km2)']
area
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b7659a3d7ed7> in <module>
# ----> 1 area = dataset.iloc[x]['Total Area (km2)']
#       2 area
#
# NameError: name 'x' is not defined

# %% [markdown]
# Limpando os dados da area.

# %%
dataset['Total Area (km2)'] = dataset['Total Area (km2)'].str.replace(',', '.')
dataset['Total Area (km2)'] = dataset['Total Area (km2)'].str.replace('.', '')

# %%
for x in range(len(dataset['Total Area (km2)'])): #inspeciona todo o dataset
    area = dataset.iloc[x]['Total Area (km2)'] # seleciona cada linha do df
    if ('sq\xa0mi' in area): #Substitue o km2
        area = area.split('-')[0] #Limpa os espaços em branco
        area = re.sub(r'[^0-9.]+', '', area)#Substitue os re
    else:
        area = area.split('-')[0]
        area = re.sub(r'[^0-9.]+', '', area)
        area = int(float(area))
    dataset.iloc[x]['Total Area (km2)'] = area

dataset.head(5)
# Out:
#          Country      US$ Total Area (km2) Percentage Water  \
# 0     Luxembourg  113,196           258642             0.60
# 1    Switzerland   83,716           412852              4.2
# 2          Macau   81,151            11532             73.7
# 3         Norway   77,975          3852072              5.7
# 4        Ireland   77,771           702732             2.00
#
#     Total Nominal GDP Per Capita GDP
# 0    $69.453 billion       $113,196
# 1       $704 billion        $82,950
# 2    $54.545 billion        $81,728
# 3       $443 billion        $82,711
# 4   $384.940 billion        $77,771

# %% [markdown]
# - Agora iniciaremos a limpezas dos dados da coluna 'Percentage Water'

# %%
dataset['Percentage Water'].head(50)
# Out:
# 0            0.60
# 1             4.2
# 2            73.7
# 3             5.7
# 4            2.00
# 5             0.8
# 6             2.7
# 7            6.97
# 8       5,703,600
# 9            0.76
# 10          19.26
# 11            8.7
# 12            1.7
# 13           59.8
# 14             10
# 15              0
# 16     83,166,711
# 17           8.92
# 18            6.5
# 19            2.1
# 20    551,695 km2
# 21           1.34
# 22    125,930,000
# 23            1.6
# 24             28
# 25            2.4
# 26            1.6
# 27            0.3
# 28          0.001
# 29           1.04
# 30     negligible
# 31            8.6
# 32            0.7
# 33     negligible
# 34     negligible
# 35     23,780,452
# 36           4.45
# 37              2
# 38            0.5
# 39            0.7
# 40         0.8669
# 41         0.0789
# 42           1.35
# 43     Negligible
# 44          1.57%
# 45     negligible
# 46     Negligible
# 47     negligible
# 48            3.7
# 49     negligible
# Name: Percentage Water, dtype: object

# %% [markdown]
# - Como se pode ver os dados contém algumas linha 'neglibes', levando assim para não deletar as mesas devemso substituir por 0.0.
#
# - Para as colunas em que o valor é superior a 100, os valores reais estavam ausentes e outro conteúdo foi lido. Portanto, devemos remover essas linhas devido à falta de informações.

# %%
dataset['Percentage Water'] = dataset['Percentage Water'].replace('negligible', '0.0')
dataset['Percentage Water'] = dataset['Percentage Water'].replace('Negligible', '0.0')
dataset['Percentage Water'] = dataset['Percentage Water'].str.replace(r'[^0-9.]+', '')

dataset['Percentage Water'] = dataset['Percentage Water'].replace(',', '.')

#Tranformando a coluna em float, com o seguinte algoritmo:

dataset['Percentage Water'] = pd.to_numeric(dataset['Percentage Water'], errors='coerce')

#Sustitue caso o resultado apareça menor que 100.

dataset = dataset[dataset['Percentage Water'].astype(float) <= 100]

# %%
print (dataset.dtypes)
# Out:
# Country               object
# US$                   object
# Total Area (km2)      object
# Percentage Water     float64
# Total Nominal GDP     object
# Per Capita GDP        object
# dtype: object

# %%
dataset['Percentage Water'].head(50)
# Out:
# 0      0.6000
# 1      4.2000
# 2     73.7000
# 3      5.7000
# 4      2.0000
# 5      0.8000
# 6      2.7000
# 7      6.9700
# 9      0.7600
# 10    19.2600
# 11     8.7000
# 12     1.7000
# 13    59.8000
# 14    10.0000
# 15     0.0000
# 17     8.9200
# 18     6.5000
# 19     2.1000
# 21     1.3400
# 23     1.6000
# 24    28.0000
# 25     2.4000
# 26     1.6000
# 27     0.3000
# 28     0.0010
# 29     1.0400
# 30     0.0000
# 31     8.6000
# 32     0.7000
# 33     0.0000
# 34     0.0000
# 36     4.4500
# 37     2.0000
# 38     0.5000
# 39     0.7000
# 40     0.8669
# 41     0.0789
# 42     1.3500
# 43     0.0000
# 44     1.5700
# 45     0.0000
# 46     0.0000
# 47     0.0000
# 48     3.7000
# 49     0.0000
# 50     1.5000
# 51     0.0000
# 52     0.0000
# 53     2.9000
# 54     1.0700
# Name: Percentage Water, dtype: float64

# %%
dataset.tail(50)
# Out:
#                                 Country    US$ Total Area (km2)  \
# 125                             Vietnam  2,740          3312122
# 126                                Laos  2,670          2379552
# 128                           Venezuela  2,547          9164452
# 129              Congo, Republic of the  2,534          3420002
# 130                          East Timor  2,262           150072
# 131                     Solomon Islands  2,246           284002
# 132                               Ghana  2,223          2395672
# 133                             Nigeria  2,222          9237692
# 134                               India  2,171         32872632
# 135                               Kenya  1,997          5803672
# 136               São Tomé and Príncipe  1,933            10012
# 137                           Nicaragua  1,919          1303752
# 138                          Bangladesh  1,905          1484602
# 139                          Uzbekistan  1,831          4489782
# 140                       Côte d'Ivoire  1,691          3224632
# 141                            Cambodia  1,620          1810352
# 143                            Cameroon  1,514          4754422
# 144                             Senegal  1,427          1967122
# 145                          Mauritania  1,392         10300002
# 146                            Pakistan  1,388          8819132
# 147                             Comoros  1,349            16592
# 148                             Lesotho  1,338           303552
# 149                              Zambia  1,307          7526182
# 150                          Kyrgyzstan  1,292          1999512
# 151                             Myanmar  1,244          6765782
# 152                               Benin  1,216          1147632
# 153                            Tanzania  1,104          9473032
# 154                               Nepal  1,047          1475162
# 155                              Guinea    981          2458572
# 156                            Ethiopia    953         11043002
# 157                          Tajikistan    877          1431002
# 158                                Chad    861         12840002
# 159                            Zimbabwe    859          3907572
# 160                              Rwanda    824           263382
# 161                       Guinea-Bissau    786           361252
# 162                               Haiti    784           277502
# 163                              Uganda    770          2410382
# 164                         Gambia, The    755           106892
# 165                        Burkina Faso    717          2742002
# 167                             Liberia    703          1113692
# 168                                Togo    671           567852
# 169                        Sierra Leone    546           717402
# 170                         Afghanistan    513          6522302
# 171   Congo, Democratic Republic of the    500         23454092
# 172                          Mozambique    484          8015902
# 174            Central African Republic    447          6229842
# 175                               Niger    405         12670002
# 176                              Malawi    370          1184842
# 177                             Eritrea    342          1176002
# 178                             Burundi    309           278342
#
#      Percentage Water   Total Nominal GDP Per Capita GDP
# 125            6.3800   $261.637 billion         $2,740
# 126            2.0000   US$20.153 billion      US$2,670
# 128            3.2000    $70.140 billion         $2,548
# 129            3.3000     $11.162 billion         $2,444
# 130            0.0000      $3.145 billion         $2,422
# 131            3.2000      $1.511 billion         $2,357
# 132            4.6100     $69.757 billion         $2,266
# 133            1.4000    $504.57 billion         $2,465
# 134            9.6000    $3.202 trillion         $2,338
# 135            2.3000    $109.116 billion         $2,151
# 136            0.0000        $355 million         $1,668
# 137            7.1400    $13.380 billion         $2,126
# 138            6.4000   $347.991 billion         $2,173
# 139            4.9000    $60.490 billion         $1,831
# 140            1.4000     $58.792 billion         $2,286
# 141            2.5000     $26.628 billion         $1,614
# 143            0.5700    $38.445 billion         $1,544
# 144            2.1000     $28.02 billion         $1,675
# 145            0.0300     $5.200 billion         $1,309
# 146            2.8600     $284.2 billion         $1,388
# 147            0.0000     $1.179 billion         $1,349
# 148            0.0032      $2.721 billion         $1,413
# 149            1.0000     $23.137 billion         $1,342
# 150            3.6000     $8.261 billion         $1,293
# 151            3.0600        $66 billion         $1,245
# 152            0.4000    $11.386 billion           $971
# 153            6.4000     $61.032 billion         $1,172
# 154            2.8000        $30 billion         $1,048
# 155            0.0000      $9.183 billion           $818
# 156            0.7000    $103.607 billion         $1,066
# 157            1.8000     $7.350 billion           $807
# 158            1.9000        $11 billion           $890
# 159            1.0000     $22.290 billion         $1,424
# 160            5.3000     $10.211 billion           $830
# 161           22.4000      $1.480 billion           $851
# 162            0.7000     $7.897 billion           $719
# 163           15.3900     $30.765 billion           $833
# 164           11.5000      $1.038 billion           $488
# 165            0.1460     $16.226 billion           $792
# 167           13.5140      $3.221 billion           $704
# 168            4.2000      $5.592 billion           $682
# 169            1.1000      $3.824 billion           $505
# 170            0.0000    $21.657 billion           $601
# 171            3.3200     $46.117 billion           $501
# 172            2.2000     $15.372 billion           $493
# 174            0.0000      $2.003 billion           $401
# 175            0.0200     $9.869 billion           $510
# 176           20.6000      $7.436 billion           $367
# 177            0.1400     $8.116 billion         $1,295
# 178           10.0000      $3.573 billion           $310

# %% [markdown]
# - O PIB total inclui os valores na forma de trilhões, bilhões e milhões. Podemos remover $ e converter as palavras em números.

# %%
dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].str.replace('$', '')
dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].str.replace('US', '')

# %%
dataset['Per Capita GDP'] = dataset['Per Capita GDP'].str.replace('$', '')
dataset['Per Capita GDP'] = dataset['Per Capita GDP'].str.replace('US', '')
# Out:
# C:\Users\Andre\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Andre\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset.tail(20)
# Out:
#                                 Country  US$ Total Area (km2)  \
# 157                          Tajikistan  877          1431002
# 158                                Chad  861         12840002
# 159                            Zimbabwe  859          3907572
# 160                              Rwanda  824           263382
# 161                       Guinea-Bissau  786           361252
# 162                               Haiti  784           277502
# 163                              Uganda  770          2410382
# 164                         Gambia, The  755           106892
# 165                        Burkina Faso  717          2742002
# 167                             Liberia  703          1113692
# 168                                Togo  671           567852
# 169                        Sierra Leone  546           717402
# 170                         Afghanistan  513          6522302
# 171   Congo, Democratic Republic of the  500         23454092
# 172                          Mozambique  484          8015902
# 174            Central African Republic  447          6229842
# 175                               Niger  405         12670002
# 176                              Malawi  370          1184842
# 177                             Eritrea  342          1176002
# 178                             Burundi  309           278342
#
#      Percentage Water Total Nominal GDP Per Capita GDP
# 157             1.800    7.350 billion           $807
# 158             1.900       11 billion           $890
# 159             1.000    22.290 billion         $1,424
# 160             5.300    10.211 billion           $830
# 161            22.400     1.480 billion           $851
# 162             0.700    7.897 billion           $719
# 163            15.390    30.765 billion           $833
# 164            11.500     1.038 billion           $488
# 165             0.146    16.226 billion           $792
# 167            13.514     3.221 billion           $704
# 168             4.200     5.592 billion           $682
# 169             1.100     3.824 billion           $505
# 170             0.000   21.657 billion           $601
# 171             3.320    46.117 billion           $501
# 172             2.200    15.372 billion           $493
# 174             0.000     2.003 billion           $401
# 175             0.020    9.869 billion           $510
# 176            20.600     7.436 billion           $367
# 177             0.140    8.116 billion         $1,295
# 178            10.000     3.573 billion           $310

# %%
#dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].str.replace('$', '')
#dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].str.replace('US', '')

for x in range(len(dataset['Total Nominal GDP'])):
    gdp = dataset.iloc[x]['Total Nominal GDP']
    if ('trillion' in dataset.iloc[x]['Total Nominal GDP']):
        gdp = re.sub(r'[^0-9.]+', '', gdp)
        gdp = int(float(gdp) * 1000000000000)
    elif ('billion' in dataset.iloc[x]['Total Nominal GDP']):
        gdp = re.sub(r'[^0-9.]+', '', gdp)
        gdp = int(float(gdp) * 1000000000)
    elif ('million' in dataset.iloc[x]['Total Nominal GDP']):
        gdp = re.sub(r'[^0-9.]+', '', gdp)
        gdp = int(float(gdp) * 1000000)
    else:
        gdp = int(re.sub(r'[^0-9.]+', '', gdp))
    dataset.iloc[x]['Total Nominal GDP'] = gdp
# Out:
# C:\Users\Andre\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].str.extract(r"(\d)", expand = False)
# replace nan (previously zero) with 2
dataset['Total Nominal GDP'].fillna(2, inplace = True)
# convert to int
dataset['Total Nominal GDP'] = dataset['Total Nominal GDP'].astype(int)
dataset.tail()

# %%
dataset.tail(50)
# Out:
#                                 Country    US$ Total Area (km2)  \
# 125                             Vietnam  2,740          3312122
# 126                                Laos  2,670          2379552
# 128                           Venezuela  2,547          9164452
# 129              Congo, Republic of the  2,534          3420002
# 130                          East Timor  2,262           150072
# 131                     Solomon Islands  2,246           284002
# 132                               Ghana  2,223          2395672
# 133                             Nigeria  2,222          9237692
# 134                               India  2,171         32872632
# 135                               Kenya  1,997          5803672
# 136               São Tomé and Príncipe  1,933            10012
# 137                           Nicaragua  1,919          1303752
# 138                          Bangladesh  1,905          1484602
# 139                          Uzbekistan  1,831          4489782
# 140                       Côte d'Ivoire  1,691          3224632
# 141                            Cambodia  1,620          1810352
# 143                            Cameroon  1,514          4754422
# 144                             Senegal  1,427          1967122
# 145                          Mauritania  1,392         10300002
# 146                            Pakistan  1,388          8819132
# 147                             Comoros  1,349            16592
# 148                             Lesotho  1,338           303552
# 149                              Zambia  1,307          7526182
# 150                          Kyrgyzstan  1,292          1999512
# 151                             Myanmar  1,244          6765782
# 152                               Benin  1,216          1147632
# 153                            Tanzania  1,104          9473032
# 154                               Nepal  1,047          1475162
# 155                              Guinea    981          2458572
# 156                            Ethiopia    953         11043002
# 157                          Tajikistan    877          1431002
# 158                                Chad    861         12840002
# 159                            Zimbabwe    859          3907572
# 160                              Rwanda    824           263382
# 161                       Guinea-Bissau    786           361252
# 162                               Haiti    784           277502
# 163                              Uganda    770          2410382
# 164                         Gambia, The    755           106892
# 165                        Burkina Faso    717          2742002
# 167                             Liberia    703          1113692
# 168                                Togo    671           567852
# 169                        Sierra Leone    546           717402
# 170                         Afghanistan    513          6522302
# 171   Congo, Democratic Republic of the    500         23454092
# 172                          Mozambique    484          8015902
# 174            Central African Republic    447          6229842
# 175                               Niger    405         12670002
# 176                              Malawi    370          1184842
# 177                             Eritrea    342          1176002
# 178                             Burundi    309           278342
#
#      Percentage Water  Total Nominal GDP Per Capita GDP
# 125            6.3800   261.637 billion          2,740
# 126            2.0000     20.153 billion         2,670
# 128            3.2000    70.140 billion          2,548
# 129            3.3000     11.162 billion          2,444
# 130            0.0000      3.145 billion          2,422
# 131            3.2000      1.511 billion          2,357
# 132            4.6100     69.757 billion          2,266
# 133            1.4000    504.57 billion          2,465
# 134            9.6000    3.202 trillion          2,338
# 135            2.3000    109.116 billion          2,151
# 136            0.0000        355 million          1,668
# 137            7.1400    13.380 billion          2,126
# 138            6.4000   347.991 billion          2,173
# 139            4.9000    60.490 billion          1,831
# 140            1.4000     58.792 billion          2,286
# 141            2.5000     26.628 billion          1,614
# 143            0.5700    38.445 billion          1,544
# 144            2.1000     28.02 billion          1,675
# 145            0.0300     5.200 billion          1,309
# 146            2.8600     284.2 billion          1,388
# 147            0.0000     1.179 billion          1,349
# 148            0.0032      2.721 billion          1,413
# 149            1.0000     23.137 billion          1,342
# 150            3.6000     8.261 billion          1,293
# 151            3.0600        66 billion          1,245
# 152            0.4000    11.386 billion            971
# 153            6.4000     61.032 billion          1,172
# 154            2.8000        30 billion          1,048
# 155            0.0000      9.183 billion            818
# 156            0.7000    103.607 billion          1,066
# 157            1.8000     7.350 billion            807
# 158            1.9000        11 billion            890
# 159            1.0000     22.290 billion          1,424
# 160            5.3000     10.211 billion            830
# 161           22.4000      1.480 billion            851
# 162            0.7000     7.897 billion            719
# 163           15.3900     30.765 billion            833
# 164           11.5000      1.038 billion            488
# 165            0.1460     16.226 billion            792
# 167           13.5140      3.221 billion            704
# 168            4.2000      5.592 billion            682
# 169            1.1000      3.824 billion            505
# 170            0.0000    21.657 billion            601
# 171            3.3200     46.117 billion            501
# 172            2.2000     15.372 billion            493
# 174            0.0000      2.003 billion            401
# 175            0.0200     9.869 billion            510
# 176           20.6000      7.436 billion            367
# 177            0.1400     8.116 billion          1,295
# 178           10.0000      3.573 billion            310

# %%
dataset.to_csv("Final_dataset.csv", index = False)
